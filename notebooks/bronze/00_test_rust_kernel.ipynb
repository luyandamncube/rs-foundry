// %%
:dep serde_json = "1"

println!("rs-foundry notebook is working");
// Out:
// rs-foundry notebook is working

// %%
use std::fs;

let path = "/workspace/data/silver/conformed/load_date=2026-03-15/ref_bronze_run_id=56e2508f-dd42-419d-a417-5b4d36ee51c7/daily_bronze_run_id=e358cb13-b4b9-4fe5-8685-02013cfc65ae/silver_conformed.json";

let content = fs::read_to_string(path)?;
println!("{}", content);
// Out:
// [
//   {
//     "event_id": "E001",
//     "ref_id": "R001",
//     "ref_name": "Alpha",
//     "ref_type": "site",
//     "ref_name_normalized": "alpha",
//     "ref_type_normalized": "site",
//     "ref_is_active": true,
//     "event_date": "2026-03-14",
//     "metric_value": 10.5,
//     "status": "ok",
//     "status_normalized": "ok",
//     "is_positive_metric": true,
//     "source_ts": null,
//     "ref_bronze_run_id": "56e2508f-dd42-419d-a417-5b4d36ee51c7",
//     "daily_bronze_run_id": "e358cb13-b4b9-4fe5-8685-02013cfc65ae",
//     "silver_built_at": "2026-03-15T00:05:59.115473817Z",
//     "load_date": "2026-03-15"
//   },
//   {
//     "event_id": "E002",
//     "ref_id": "R002",
//     "ref_name": "Beta",
//     "ref_type": "site",
//     "ref_name_normalized": "beta",
//     "ref_type_normalized": "site",
//     "ref_is_active": true,
//     "event_date": "2026-03-14",
//     "metric_value": 25.0,
//     "status": "warning",
//     "status_normalized": "warning",
// ...
